# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
a_file = '/home/workspace/iot_ai_model/dataset/digital_digit/anno_digit.txt'

# %%
with open(a_file, 'r') as f:
    annotation = f.readlines()

# %%
cols = annotation[0].strip().split()
filename = cols[0]
objects = cols[1:]

# %%
filename
# Out:
# 'images/clock38.jpg'

# %%
obj = objects[0]
box = np.array(obj.split(','), dtype = np.int)

# %%
img = cv2.imread('dataset/digital_digit/' + filename)

# %%
output_img = cv2.rectangle(img, (box[0], box[1]), (box[2], box[3]), (0,0,255), 2)

# %%
output_img = cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(output_img)
plt.show()

# %%
# x : 750

# %%
a_file = '/home/workspace/iot_ai_model/dataset/digital_digit/anno_digit.txt'
with open(a_file, 'r') as f:
    annotations = f.readlines()

# %%
for anno in annotations:
    cols = anno.strip().split()
    filename = cols[0]
    
    gay_image = cv2.imread(f'dataset/digital_digit/{filename}')
    
    red_iamge = cv2.imread(f'dataset/digital_digit/{filename}')
    
    
    
    plt.imshow(img)
    plt.show()
    
    for obj in cols[1:]:
        box = np.array(obj.split(','), dtype = np.int)
        
        # gray_clock
        if box[0] > 750:
            img = cv2.rectangle(img, (box[0], box[1]), (box[2], box[3]), (114, 114, 114), -1)
        
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    plt.show()
    
    break
    # red_clock
