# %%
import backbone
import tensorflow as tf

# %%
tf.random.random((416,416,3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-71b5d0a53328> in <module>
# ----> 1 tf.random.random((416,416,3))
#
# AttributeError: module 'tensorflow._api.v2.random' has no attribute 'random'

# %%
input_layer = tf.keras.layers.Input([416, 416, 3])

out1,out2,out3 = backbone.cspdarknet53(input_layer)

# %%
model = tf.keras.Model(input_layer, [out1,out2,out3])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 416, 416, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 416, 416, 32) 128         conv2d_157[0][0]
# __________________________________________________________________________________________________
# tf.math.softplus_144 (TFOpLambd (None, 416, 416, 32) 0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from yolo import createModeForTRT

# %%
input_size = 416
num_class = 10
anchors = [23,27, 37,58, 81,82, 81,82, 135,169, 344,319]
strides = [16, 32]
xyscale = [1.05, 1.05]

model = createModeForTRT(num_class, input_size, strides, anchors, xyscale)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 416, 416, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 417, 417, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 208, 208, 32) 864         zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 208, 208, 32) 128         conv2d_256[0][0]
# __________________________________________________________________________________________________
# ...

# %%
from glob import glob

# %%
len(glob('/home/workspace/iot_ai_model/dataset/vibration/train/**/**/def_shaft_alignment/*.csv'))
# Out:
# 14826
