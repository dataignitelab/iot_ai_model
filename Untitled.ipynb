# %%
from PIL import Image
import cv2,os
import numpy as np

from matplotlib import pyplot as plt

# %%
img = cv2.imread('/home/workspace/iot_ai_model/dataset/supervisely_person/images/ds6_pexels-photo-264384.png')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
mask = cv2.imread('/home/workspace/iot_ai_model/dataset/supervisely_person/masks/ds6_pexels-photo-264384.png')

# %%
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
plt.imshow(mask)

# %%
img =img.astype(np.int16)
green = np.zeros_like(mask)
green[:,:,1] = mask[:,:,1]
img[green >= 255] = img[green >= 255] * 3
img[img >= 255] = 255

other = np.zeros_like(mask)
other[:,:,[0,2]] = mask[:,:,[0,2]] 
img[other >= 255] = img[other >= 255] * 0.3

# %%
plt.imshow(img)
